# %% [markdown]
# <a href="https://colab.research.google.com/github/BootCamp-BMA/colabs/blob/main/extract_embedding_dziriBert_classify_byRandomForest_SVM_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
import torch
from transformers import BertTokenizer, BertModel
from google.colab import drive
import os

# ===========================
# 1️⃣ MOUNT GOOGLE DRIVE
# ===========================
drive.mount('/content/drive')

# Define dataset paths
base_path = "/content/drive/My Drive/fake-news/"
train_path = os.path.join(base_path, "train_set.csv")
test_path = os.path.join(base_path, "test_set.csv")
val_path = os.path.join(base_path, "validation_set.csv")

# ===========================
# 2️⃣ LOAD DATASETS
# ===========================
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)
val_df = pd.read_csv(val_path)

# ===========================
# 3️⃣ CLEAN ARABIC TEXT
# ===========================
def clean_text(text):
    text = re.sub(r"[^\w\s]", "", text)  # Remove punctuation
    text = re.sub(r"\d+", "", text)  # Remove numbers
    text = text.strip()
    return text

# Apply cleaning
train_df["text"] = train_df["text"].astype(str).apply(clean_text)
test_df["text"] = test_df["text"].astype(str).apply(clean_text)
val_df["text"] = val_df["text"].astype(str).apply(clean_text)

# ===========================
# 4️⃣ LOAD DZIRIBERT TOKENIZER & MODEL
# ===========================
model_name = "alger-ia/dziribert"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

# ===========================
# 5️⃣ EXTRACT BERT EMBEDDINGS
# ===========================
import numpy as np

# Function to process embeddings in small batches
def extract_embeddings(texts, batch_size=16):
    all_embeddings = []
    num_batches = (len(texts) + batch_size - 1) // batch_size  # Calculate total batches

    for i in range(num_batches):
        batch_texts = texts[i * batch_size:(i + 1) * batch_size]  # Get batch
        inputs = tokenizer(batch_texts, padding=True, truncation=True, return_tensors="pt", max_length=512)
        inputs = {key: value.to(device) for key, value in inputs.items()}  # Move to GPU

        with torch.no_grad():
            outputs = model(**inputs)

        embeddings = outputs.last_hidden_state[:, 0, :].cpu().numpy()  # CLS token
        all_embeddings.append(embeddings)

        print(f"Processed batch {i+1}/{num_batches}")  # Track progress

    return np.vstack(all_embeddings)  # Stack all batches

# Run extraction with batch processing
train_embeddings = extract_embeddings(train_df["text"].tolist(), batch_size=16)
test_embeddings = extract_embeddings(test_df["text"].tolist(), batch_size=16)
val_embeddings = extract_embeddings(val_df["text"].tolist(), batch_size=16)


# Convert text to embeddings
train_embeddings = extract_embeddings(train_df["text"].tolist())
test_embeddings = extract_embeddings(test_df["text"].tolist())
val_embeddings = extract_embeddings(val_df["text"].tolist())

# ===========================
# 6️⃣ SAVE EMBEDDINGS TO GOOGLE DRIVE
# ===========================
save_path = "/content/drive/My Drive/fake-news-embeddings/"

# Create directory if it doesn’t exist
os.makedirs(save_path, exist_ok=True)

pd.DataFrame(train_embeddings).to_csv(os.path.join(save_path, "train_embeddings.csv"), index=False)
pd.DataFrame(test_embeddings).to_csv(os.path.join(save_path, "test_embeddings.csv"), index=False)
pd.DataFrame(val_embeddings).to_csv(os.path.join(save_path, "val_embeddings.csv"), index=False)

print("✅ Embeddings saved successfully in:", save_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Some weights of BertModel were not initialized from the model checkpoint at alger-ia/dziribert and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Processed batch 1/505
# Processed batch 2/505
# Processed batch 3/505
# Processed batch 4/505
# Processed batch 5/505
# Processed batch 6/505
# Processed batch 7/505
# Processed batch 8/505
# Processed batch 9/505
# Processed batch 10/505
# Processed batch 11/505
# Processed batch 12/505
# Processed batch 13/505
# Processed batch 14/505
# Processed batch 15/505
# Processed batch 16/505
# Processed batch 17/505
# Processed batch 18/505
# Processed batch 19/505
# Processed batch 20/505
# Processed batch 21/505
# Processed batch 22/505
# Processed batch 23/505
# Processed batch 24/505
# Processed batch 25/505
# Processed batch 26/505
# Processed batch 27/505
# Processed batch 28/505
# Processed batch 29/505
# Processed batch 30/505
# Processed batch 31/505
# Processed batch 32/505
# Processed batch 33/505
# Processed batch 34/505
# Processed batch 35/505
# Processed batch 36/505
# Processed batch 37/505
# Processed batch 38/505
# Processed batch 39/505
# Processed batch 40/505
# Processed batch 41/505
# Processed batch 42/505
# Processed batch 43/505
# Processed batch 44/505
# Processed batch 45/505
# Processed batch 46/505
# Processed batch 47/505
# Processed batch 48/505
# Processed batch 49/505
# Processed batch 50/505
# Processed batch 51/505
# Processed batch 52/505
# Processed batch 53/505
# Processed batch 54/505
# Processed batch 55/505
# Processed batch 56/505
# Processed batch 57/505
# Processed batch 58/505
# Processed batch 59/505
# Processed batch 60/505
# Processed batch 61/505
# Processed batch 62/505
# Processed batch 63/505
# Processed batch 64/505
# Processed batch 65/505
# Processed batch 66/505
# Processed batch 67/505
# Processed batch 68/505
# Processed batch 69/505
# Processed batch 70/505
# Processed batch 71/505
# Processed batch 72/505
# Processed batch 73/505
# Processed batch 74/505
# Processed batch 75/505
# Processed batch 76/505
# Processed batch 77/505
# Processed batch 78/505
# Processed batch 79/505
# Processed batch 80/505
# Processed batch 81/505
# Processed batch 82/505
# Processed batch 83/505
# Processed batch 84/505
# Processed batch 85/505
# Processed batch 86/505
# Processed batch 87/505
# Processed batch 88/505
# Processed batch 89/505
# Processed batch 90/505
# Processed batch 91/505
# Processed batch 92/505
# Processed batch 93/505
# Processed batch 94/505
# Processed batch 95/505
# Processed batch 96/505
# Processed batch 97/505
# Processed batch 98/505
# Processed batch 99/505
# Processed batch 100/505
# Processed batch 101/505
# Processed batch 102/505
# Processed batch 103/505
# Processed batch 104/505
# Processed batch 105/505
# Processed batch 106/505
# Processed batch 107/505
# Processed batch 108/505
# Processed batch 109/505
# Processed batch 110/505
# Processed batch 111/505
# Processed batch 112/505
# Processed batch 113/505
# Processed batch 114/505
# Processed batch 115/505
# Processed batch 116/505
# Processed batch 117/505
# Processed batch 118/505
# Processed batch 119/505
# Processed batch 120/505
# Processed batch 121/505
# Processed batch 122/505
# Processed batch 123/505
# Processed batch 124/505
# Processed batch 125/505
# Processed batch 126/505
# Processed batch 127/505
# Processed batch 128/505
# Processed batch 129/505
# Processed batch 130/505
# Processed batch 131/505
# Processed batch 132/505
# Processed batch 133/505
# Processed batch 134/505
# Processed batch 135/505
# Processed batch 136/505
# Processed batch 137/505
# Processed batch 138/505
# Processed batch 412/505
# Processed batch 413/505
# Processed batch 414/505
# Processed batch 415/505
# Processed batch 416/505
# Processed batch 417/505
# Processed batch 418/505
# Processed batch 419/505
# Processed batch 420/505
# Processed batch 421/505
# Processed batch 422/505
# Processed batch 423/505
# Processed batch 424/505
# Processed batch 425/505
# Processed batch 426/505
# Processed batch 427/505
# Processed batch 428/505
# Processed batch 429/505
# Processed batch 430/505
# Processed batch 431/505
# Processed batch 432/505
# Processed batch 433/505
# Processed batch 434/505
# Processed batch 435/505
# Processed batch 436/505
# Processed batch 437/505
# Processed batch 438/505
# Processed batch 439/505
# Processed batch 440/505
# Processed batch 441/505
# Processed batch 442/505
# Processed batch 443/505
# Processed batch 444/505
# Processed batch 445/505
# Processed batch 446/505
# Processed batch 447/505
# Processed batch 448/505
# Processed batch 449/505
# Processed batch 450/505
# Processed batch 451/505
# Processed batch 452/505
# Processed batch 453/505
# Processed batch 454/505
# Processed batch 455/505
# Processed batch 456/505
# Processed batch 457/505
# Processed batch 458/505
# Processed batch 459/505
# Processed batch 460/505
# Processed batch 461/505
# Processed batch 462/505
# Processed batch 463/505
# Processed batch 464/505
# Processed batch 465/505
# Processed batch 466/505
# Processed batch 467/505
# Processed batch 468/505
# Processed batch 469/505
# Processed batch 470/505
# Processed batch 471/505
# Processed batch 472/505
# Processed batch 473/505
# Processed batch 474/505
# Processed batch 475/505
# Processed batch 476/505
# Processed batch 477/505
# Processed batch 478/505
# Processed batch 479/505
# Processed batch 480/505
# Processed batch 481/505
# Processed batch 482/505
# Processed batch 483/505
# Processed batch 484/505
# Processed batch 485/505
# Processed batch 486/505
# Processed batch 487/505
# Processed batch 488/505
# Processed batch 489/505
# Processed batch 490/505
# Processed batch 491/505
# Processed batch 492/505
# Processed batch 493/505
# Processed batch 494/505
# Processed batch 495/505
# Processed batch 496/505
# Processed batch 497/505
# Processed batch 498/505
# Processed batch 499/505
# Processed batch 500/505
# Processed batch 501/505
# Processed batch 502/505
# Processed batch 503/505
# Processed batch 504/505
# Processed batch 505/505
# Processed batch 1/64
# Processed batch 2/64
# Processed batch 3/64
# Processed batch 4/64
# Processed batch 5/64
# Processed batch 6/64
# Processed batch 7/64
# Processed batch 8/64
# Processed batch 9/64
# Processed batch 10/64
# Processed batch 11/64
# Processed batch 12/64
# Processed batch 13/64
# Processed batch 14/64
# Processed batch 15/64
# Processed batch 16/64
# Processed batch 17/64
# Processed batch 18/64
# Processed batch 19/64
# Processed batch 20/64
# Processed batch 21/64
# Processed batch 22/64
# Processed batch 23/64
# Processed batch 24/64
# Processed batch 25/64
# Processed batch 26/64
# Processed batch 27/64
# Processed batch 28/64
# Processed batch 29/64
# Processed batch 30/64
# Processed batch 31/64
# Processed batch 32/64
# Processed batch 33/64
# Processed batch 34/64
# Processed batch 35/64
# Processed batch 36/64
# Processed batch 37/64
# Processed batch 38/64
# Processed batch 39/64
# Processed batch 40/64
# Processed batch 41/64
# Processed batch 42/64
# Processed batch 43/64
# Processed batch 44/64
# Processed batch 45/64
# Processed batch 46/64
# Processed batch 47/64
# Processed batch 48/64
# Processed batch 49/64
# Processed batch 50/64
# Processed batch 51/64
# Processed batch 52/64
# Processed batch 53/64
# Processed batch 54/64
# Processed batch 55/64
# Processed batch 56/64
# Processed batch 57/64
# Processed batch 58/64
# Processed batch 59/64
# Processed batch 60/64
# Processed batch 61/64
# Processed batch 62/64
# Processed batch 63/64
# Processed batch 64/64
# Processed batch 1/64
# Processed batch 2/64
# Processed batch 3/64
# Processed batch 4/64
# Processed batch 5/64
# Processed batch 6/64
# Processed batch 7/64
# Processed batch 8/64
# Processed batch 9/64
# Processed batch 10/64
# Processed batch 11/64
# Processed batch 12/64
# Processed batch 13/64
# Processed batch 14/64
# Processed batch 15/64
# Processed batch 16/64
# Processed batch 17/64
# Processed batch 18/64
# Processed batch 19/64
# Processed batch 20/64
# Processed batch 21/64
# Processed batch 22/64
# Processed batch 23/64
# Processed batch 24/64
# Processed batch 25/64
# Processed batch 26/64
# Processed batch 27/64
# Processed batch 28/64
# Processed batch 29/64
# Processed batch 30/64
# Processed batch 31/64
# Processed batch 32/64
# Processed batch 33/64
# Processed batch 34/64
# Processed batch 35/64
# Processed batch 36/64
# Processed batch 37/64
# Processed batch 38/64
# Processed batch 39/64
# Processed batch 40/64
# Processed batch 41/64
# Processed batch 42/64
# Processed batch 43/64
# Processed batch 44/64
# Processed batch 45/64
# Processed batch 46/64
# Processed batch 47/64
# Processed batch 48/64
# Processed batch 49/64
# Processed batch 50/64
# Processed batch 51/64
# Processed batch 52/64
# Processed batch 53/64
# Processed batch 54/64
# Processed batch 55/64
# Processed batch 56/64
# Processed batch 57/64
# Processed batch 58/64
# Processed batch 59/64
# Processed batch 60/64
# Processed batch 61/64
# Processed batch 62/64
# Processed batch 63/64
# Processed batch 64/64
# Processed batch 1/505
# Processed batch 2/505
# Processed batch 3/505
# Processed batch 4/505
# Processed batch 5/505
# Processed batch 6/505
# Processed batch 7/505
# Processed batch 8/505
# Processed batch 9/505
# Processed batch 10/505
# Processed batch 11/505
# Processed batch 12/505
# Processed batch 13/505
# Processed batch 14/505
# Processed batch 15/505
# Processed batch 16/505
# Processed batch 17/505
# Processed batch 18/505
# Processed batch 19/505
# Processed batch 20/505
# Processed batch 21/505
# Processed batch 22/505
# Processed batch 23/505
# Processed batch 24/505
# Processed batch 25/505
# Processed batch 26/505
# Processed batch 27/505
# Processed batch 28/505
# Processed batch 29/505
# Processed batch 30/505
# Processed batch 31/505
# Processed batch 32/505
# Processed batch 33/505
# Processed batch 34/505
# Processed batch 35/505
# Processed batch 36/505
# Processed batch 37/505
# Processed batch 38/505
# Processed batch 39/505
# Processed batch 40/505
# Processed batch 41/505
# Processed batch 42/505
# Processed batch 43/505
# Processed batch 44/505
# Processed batch 45/505
# Processed batch 46/505
# Processed batch 47/505
# Processed batch 48/505
# Processed batch 49/505
# Processed batch 50/505
# Processed batch 51/505
# Processed batch 52/505
# Processed batch 464/505
# Processed batch 465/505
# Processed batch 466/505
# Processed batch 467/505
# Processed batch 468/505
# Processed batch 469/505
# Processed batch 470/505
# Processed batch 471/505
# Processed batch 472/505
# Processed batch 473/505
# Processed batch 474/505
# Processed batch 475/505
# Processed batch 476/505
# Processed batch 477/505
# Processed batch 478/505
# Processed batch 479/505
# Processed batch 480/505
# Processed batch 481/505
# Processed batch 482/505
# Processed batch 483/505
# Processed batch 484/505
# Processed batch 485/505
# Processed batch 486/505
# Processed batch 487/505
# Processed batch 488/505
# Processed batch 489/505
# Processed batch 490/505
# Processed batch 491/505
# Processed batch 492/505
# Processed batch 493/505
# Processed batch 494/505
# Processed batch 495/505
# Processed batch 496/505
# Processed batch 497/505
# Processed batch 498/505
# Processed batch 499/505
# Processed batch 500/505
# Processed batch 501/505
# Processed batch 502/505
# Processed batch 503/505
# Processed batch 504/505
# Processed batch 505/505
# Processed batch 1/64
# Processed batch 2/64
# Processed batch 3/64
# Processed batch 4/64
# Processed batch 5/64
# Processed batch 6/64
# Processed batch 7/64
# Processed batch 8/64
# Processed batch 9/64
# Processed batch 10/64
# Processed batch 11/64
# Processed batch 12/64
# Processed batch 13/64
# Processed batch 14/64
# Processed batch 15/64
# Processed batch 16/64
# Processed batch 17/64
# Processed batch 18/64
# Processed batch 19/64
# Processed batch 20/64
# Processed batch 21/64
# Processed batch 22/64
# Processed batch 23/64
# Processed batch 24/64
# Processed batch 25/64
# Processed batch 26/64
# Processed batch 27/64
# Processed batch 28/64
# Processed batch 29/64
# Processed batch 30/64
# Processed batch 31/64
# Processed batch 32/64
# Processed batch 33/64
# Processed batch 34/64
# Processed batch 35/64
# Processed batch 36/64
# Processed batch 37/64
# Processed batch 38/64
# Processed batch 39/64
# Processed batch 40/64
# Processed batch 41/64
# Processed batch 42/64
# Processed batch 43/64
# Processed batch 44/64
# Processed batch 45/64
# Processed batch 46/64
# Processed batch 47/64
# Processed batch 48/64
# Processed batch 49/64
# Processed batch 50/64
# Processed batch 51/64
# Processed batch 52/64
# Processed batch 53/64
# Processed batch 54/64
# Processed batch 55/64
# Processed batch 56/64
# Processed batch 57/64
# Processed batch 58/64
# Processed batch 59/64
# Processed batch 60/64
# Processed batch 61/64
# Processed batch 62/64
# Processed batch 63/64
# Processed batch 64/64
# Processed batch 1/64
# Processed batch 2/64
# Processed batch 3/64
# Processed batch 4/64
# Processed batch 5/64
# Processed batch 6/64
# Processed batch 7/64
# Processed batch 8/64
# Processed batch 9/64
# Processed batch 10/64
# Processed batch 11/64
# Processed batch 12/64
# Processed batch 13/64
# Processed batch 14/64
# Processed batch 15/64
# Processed batch 16/64
# Processed batch 17/64
# Processed batch 18/64
# Processed batch 19/64
# Processed batch 20/64
# Processed batch 21/64
# Processed batch 22/64
# Processed batch 23/64
# Processed batch 24/64
# Processed batch 25/64
# Processed batch 26/64
# Processed batch 27/64
# Processed batch 28/64
# Processed batch 29/64
# Processed batch 30/64
# Processed batch 31/64
# Processed batch 32/64
# Processed batch 33/64
# Processed batch 34/64
# Processed batch 35/64
# Processed batch 36/64
# Processed batch 37/64
# Processed batch 38/64
# Processed batch 39/64
# Processed batch 40/64
# Processed batch 41/64
# Processed batch 42/64
# Processed batch 43/64
# Processed batch 44/64
# Processed batch 45/64
# Processed batch 46/64
# Processed batch 47/64
# Processed batch 48/64
# Processed batch 49/64
# Processed batch 50/64
# Processed batch 51/64
# Processed batch 52/64
# Processed batch 53/64
# Processed batch 54/64
# Processed batch 55/64
# Processed batch 56/64
# Processed batch 57/64
# Processed batch 58/64
# Processed batch 59/64
# Processed batch 60/64
# Processed batch 61/64
# Processed batch 62/64
# Processed batch 63/64
# Processed batch 64/64
# ✅ Embeddings saved successfully in: /content/drive/My Drive/fake-news-embeddings/

# %%
import os
import pandas as pd

# Define saved embedding paths
save_path = "/content/drive/My Drive/fake-news-embeddings/"

# Load embeddings
X_train = pd.read_csv(os.path.join(save_path, "train_embeddings.csv")).values
X_test = pd.read_csv(os.path.join(save_path, "test_embeddings.csv")).values
X_val = pd.read_csv(os.path.join(save_path, "val_embeddings.csv")).values

# Load original datasets to get labels
base_path = "/content/drive/My Drive/fake-news/"
train_df = pd.read_csv(os.path.join(base_path, "train_set.csv"))
test_df = pd.read_csv(os.path.join(base_path, "test_set.csv"))
val_df = pd.read_csv(os.path.join(base_path, "validation_set.csv"))

# Extract labels
y_train = train_df["label"].values
y_test = test_df["label"].values
y_val = val_df["label"].values

print("✅ Embeddings & Labels Loaded Successfully!")
# Out:
# ✅ Embeddings & Labels Loaded Successfully!

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Train Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Make predictions
y_pred = clf.predict(X_test)

# Evaluate model
print("✅ Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# ✅ Accuracy: 0.6372646184340932
#               precision    recall  f1-score   support
#
#            0       0.63      0.76      0.69       540
#            1       0.64      0.49      0.56       469
#
#     accuracy                           0.64      1009
#    macro avg       0.64      0.63      0.63      1009
# weighted avg       0.64      0.64      0.63      1009

# %%
from sklearn.svm import SVC

# Train SVM classifier
svm_clf = SVC(kernel="linear", C=1.0, random_state=42)
svm_clf.fit(X_train, y_train)

# Predict
y_pred_svm = svm_clf.predict(X_test)

# Evaluate
print("✅ SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))
# Out:
# ✅ SVM Accuracy: 0.624380574826561
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65       540
#            1       0.60      0.59      0.60       469
#
#     accuracy                           0.62      1009
#    macro avg       0.62      0.62      0.62      1009
# weighted avg       0.62      0.62      0.62      1009

# %%
# Predict on validation set
y_val_pred = clf.predict(X_val)

# Evaluate
print("✅ Validation Accuracy:", accuracy_score(y_val, y_val_pred))
print(classification_report(y_val, y_val_pred))
# Out:
# ✅ Validation Accuracy: 0.6313181367690783
#               precision    recall  f1-score   support
#
#            0       0.63      0.75      0.69       539
#            1       0.63      0.49      0.55       470
#
#     accuracy                           0.63      1009
#    macro avg       0.63      0.62      0.62      1009
# weighted avg       0.63      0.63      0.62      1009
